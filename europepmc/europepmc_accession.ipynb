# %% [markdown]
# # EuropePMC accession number data descriptive stats
#
# Publication -> data accession numbers are available from EuropePMC. These can be linked to the Data Citation Corpus using DOIs for publications and accession numbers (or DOIs in some cases) for datasets. See [README](README.md) for more details.

# %% [markdown]
# ## Setup:

# %%
from pathlib import Path
import re
import json

# %%
from download_data import load_accession_data, accession_csv_to_dataframe, prepare_concatenated_dataframe, postprocess_europepmc_accession_data

# %%
import pandas as pd
import numpy as np

# %%
import logging
logging.getLogger('backoff').addHandler(logging.StreamHandler())
logging.getLogger('backoff').setLevel(logging.INFO)

# %%
def get_accession_dataframe(data_directory=None, postprocess=True):
    if data_directory is None:
        # default is to download the data from EuropePMC
        return load_accession_data(postprocess=postprocess)
    else:
        csv_files = Path(data_directory).glob("*.csv")
        _dfs = []
        for file in csv_files:
            _dfs.append(accession_csv_to_dataframe(file, file.name))
        df_acc = prepare_concatenated_dataframe(_dfs)
        if postprocess is True:
            df_acc = postprocess_europepmc_accession_data(df_acc)
        return df_acc

# %% [markdown]
# ## Get EuropePMC data
#
# We will get a dataframe where each row is a PMCID -> accession number pair.
#
# We can either: (a) download the EuropePMC accession data manually, then specify the folder with all of the CSV files:
#
# ```py
# df_acc = get_accession_dataframe("<path_to_folder>", postprocess=True)
# ```
#
# or, (b) download the data on the fly:
#
# ```py
# df_acc = get_accession_dataframe(postprocess=True)
# ```
#
# The data will look something like:
#
# ```mermaid
# erDiagram
#     EUROPEPMC["EuropePMC Accession Number Citation"] {
#         string accession_number PK
#         string PMCID PK
#         category repository_europepmc
#     }
# ```

# %%
df_acc = get_accession_dataframe(postprocess=True)
# Out:
# Backing off make_request(...) for 0.7s (requests.exceptions.HTTPError: 502 Server Error: Proxy Error for url: https://europepmc.org/ftp/TextMinedTerms/hipsci.csv)
# Backing off make_request(...) for 0.7s (requests.exceptions.HTTPError: 502 Server Error: Proxy Error for url: https://europepmc.org/ftp/TextMinedTerms/hipsci.csv)

# %%
df_acc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7871913 entries, 0 to 8174537
# Data columns (total 5 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   accession_number      string
#  1   PMCID                 string
#  2   EXTID                 string
#  3   SOURCE                string
#  4   repository_europepmc  category
# dtypes: category(1), string(4)
# memory usage: 307.8 MB

# %% [markdown]
# ## Get Corpus data
#
# I'm using a preprocessed file I made from the downloaded Corpus data.
#
# The data will look something like (some columns omitted):
#
# ```mermaid
# erDiagram
#     CORPUS["Corpus Citation"] {
#         string id PK
#         string publication_id "Currently only DOI allowed"
#         string dataset_id "DOI or accession number"
#         category repository "not necessarily matched to the EuropePMC repository"
#         bool publication_is_doi
#         bool dataset_is_doi
#     }
# ```

# %%
cols = ['publisher', 'journal', 'repository', 'publication', 'dataset', 'publication_is_doi', 'dataset_is_doi', 'publishedDate', 'source']
df_corpus = pd.read_parquet('../data/df_2024-08-23-data-citation-corpus-v2.0.parquet', columns=cols)

# %%
df_corpus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5256114 entries, 61b9de16-8243-4802-b9d9-d04b7c46948e to 30ea1b0e-057f-4cfe-9566-080eaa184706
# Data columns (total 9 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   publisher           category
#  1   journal             category
#  2   repository          category
#  3   publication         string
#  4   dataset             string
#  5   publication_is_doi  bool
#  6   dataset_is_doi      bool
#  7   publishedDate       datetime64[ns, UTC]
#  8   source              category
# dtypes: bool(2), category(4), datetime64[ns, UTC](1), string(2)
# memory usage: 206.3+ MB

# %% [markdown]
# ## Get DOI data from EuropePMC
#
# The data file from EuropePMC links DOI to one or both of PMID/PMCID. We will only use the data linking PMCID to DOI.

# %%
# Load DOI data (frome EuropePMC)
import sys
sys.path.append('..')
from clean_doi import clean_doi
fp = Path('../data/europepmc/PMID_PMCID_DOI.csv.gz')
df_pmid_doi = pd.read_csv(fp)
print(f"dataframe shape {df_pmid_doi.shape}")
df_pmid_doi = df_pmid_doi.dropna(subset=['PMCID', 'DOI'])
print(f"dataframe shape {df_pmid_doi.shape}")
df_pmid_doi['DOI'] = df_pmid_doi['DOI'].apply(clean_doi, return_none_if_error=True)
df_pmid_doi = df_pmid_doi.drop_duplicates(subset=['PMCID', 'DOI'])
print(f"dataframe shape {df_pmid_doi.shape}")
# Out:
# dataframe shape (39155263, 3)
# dataframe shape (8849412, 3)
# dataframe shape (8848632, 3)

# %%
df_acc = df_acc.merge(df_pmid_doi, how='left', on='PMCID')

# %%
df_acc['DOI'].isna().value_counts()
# Out:
# DOI
# False    7736494
# True      188480
# Name: count, dtype: int64

# %%
# how many Corpus publication DOIs have PMCID?
corpus_dois = df_corpus[df_corpus['publication_is_doi']==True]['publication'].unique()
europepmc_dois = df_pmid_doi['DOI'].unique()
doi_intersection = set.intersection(set(corpus_dois), set(europepmc_dois))
print(f"There are {len(corpus_dois):,} publication DOIs in the Corpus.")
print(f"{len(doi_intersection):,} ({len(doi_intersection)/len(corpus_dois):.0%}) of these have PMCID associated.")
# Out:
# There are 2,024,203 publication DOIs in the Corpus.
# 1,420,535 (70%) of these have PMCID associated.

# %% [markdown]
# Desired descriptive stats table:
#
# ```mermaid
# erDiagram
#     REPOSITORY {
#         category repository_europepmc PK
#         int row_count_europepmc
#     }
#     REPCORPUS["Repository in Data Corpus"] {
#         string corpus_repository PK
#         int row_count
#     }
#     REPLINK["Repository names in Corpus linked to EuropePMC"] {
#         category repository_europepmc PK, FK
#         string corpus_repository PK, FK
#         int row_count
#     }
#     REPOSITORY one to one or more REPLINK : is
#     REPCORPUS one to zero or more REPLINK : matches
# ```
#
# this will allow us to get:
#
# ```mermaid
# erDiagram
#     REPOSITORY {
#         category repository_europepmc PK
#         int row_count_europepmc
#         int count_matched_in_corpus
#         float pct_matched_in_corpus
#         string[] names_in_corpus
#     }
# ```

# %%
df_repcorpus = df_corpus[df_corpus['dataset_is_doi']==False]['repository'].value_counts().reset_index(name="row_count")
df_repcorpus = df_repcorpus[df_repcorpus["row_count"]>0]

# %%
df_repository = df_acc['repository_europepmc'].value_counts().reset_index(name="row_count_europepmc")

# %%
#upper?
acc_nums = df_acc['accession_number'].dropna()
# (acc_nums == acc_nums.str.upper()).all()
acc_nums[acc_nums!=acc_nums.str.upper()]
# Out:
# 135950     1h3iA01
# 135951     1mt6A01
# 135952     1tcvA00
# 135953     1td1B00
# 135954     1fp5A02
#             ...
# 7924903     p10347
# 7924914     p00698
# 7924924     p47733
# 7924943     H2Bub1
# 7924968     B7Sym9
# Name: accession_number, Length: 1188282, dtype: string

# %%
to_merge = df_corpus[['publication', 'dataset', 'repository']].reset_index()
to_merge = to_merge.dropna(subset=['publication', 'dataset'])
to_merge['accession_number_upper'] = to_merge['dataset'].str.upper()
to_merge = to_merge.drop(columns=['dataset'])
to_merge = to_merge.rename(columns={'publication': 'DOI', 'id': 'corpus_id', 'repository': 'corpus_repository'})
df_acc['accession_number_upper'] = df_acc['accession_number'].str.upper()
df_acc_corpus_merge = df_acc.merge(to_merge, how='left', on=['DOI', 'accession_number_upper'])

# %%
df_acc_match1 = df_acc_corpus_merge.dropna(subset=['corpus_id'])
print(f"matched {len(df_acc_match1):,} publication --> dataset citations between EuropePMC and Corpus, using exact matching on DOI and accession number")
# Out:
# matched 1,341,556 publication --> dataset citations between EuropePMC and Corpus, using exact matching on DOI and accession number

# %%
df_acc_match1
# Out:
#         accession_number       PMCID          EXTID SOURCE  \
# 1486           E-TABM-63  PMC2944327       19728874    MED
# 1492          E-MEXP-449  PMC2944327       19728874    MED
# 1494         E-MEXP-1094  PMC2944327       19728874    MED
# 1495          E-MEXP-547  PMC2944327       19728874    MED
# 1498          E-GEOD-431  PMC2944327       19728874    MED
# ...                  ...         ...            ...    ...
# 7929780           P53355  PMC2199731       10402466    MED
# 7929804           P11047  PMC2185082       10225960    MED
# 7929825           P42271  PMC2132928       10037793    MED
# 7929828           Q33211  PMC9649441  PMCPMC9649441    CTX
# 7929829           P12504  PMC8460447  PMCPMC8460447    CTX
#
#         repository_europepmc        PMID                         DOI  \
# 1486            arrayexpress  19728874.0      10.1186/1752-0509-3-86
# 1492            arrayexpress  19728874.0      10.1186/1752-0509-3-86
# 1494            arrayexpress  19728874.0      10.1186/1752-0509-3-86
# 1495            arrayexpress  19728874.0      10.1186/1752-0509-3-86
# 1498            arrayexpress  19728874.0      10.1186/1752-0509-3-86
# ...                      ...         ...                         ...
# 7929780              uniprot  10402466.0       10.1083/jcb.146.1.141
# 7929804              uniprot  10225960.0       10.1083/jcb.145.3.605
# 7929825              uniprot  10037793.0       10.1083/jcb.144.4.721
# 7929828              uniprot  36333500.0  10.1038/s41588-022-01210-z
# 7929829              uniprot  34518685.0  10.1038/s41589-021-00858-8
#
#         accession_number_upper                             corpus_id  \
# 1486                 E-TABM-63  920ae419-48d6-44bf-8c1b-56e112df5576
# 1492                E-MEXP-449  2ae1c77b-67c6-4075-a109-f8e4fff2557e
# 1494               E-MEXP-1094  ea61eb9e-0c17-47d7-8e54-eea1e8632607
# 1495                E-MEXP-547  6f788fae-7808-4856-a30f-37d7a9cc3e48
# 1498                E-GEOD-431  f2e36d1e-15fd-423b-b4be-84ad0e082db0
# ...                        ...                                   ...
# 7929780                 P53355  aae4869f-9ef6-4ccf-a23a-36d69ca7b401
# 7929804                 P11047  9629c023-674f-4474-b0cb-f97fcc85e3c5
# 7929825                 P42271  d50a7943-fa5e-4e18-8015-b6d49889bc67
# 7929828                 Q33211  ca7ffcac-1cef-4280-98cf-12c70314757c
# 7929829                 P12504  f8fca4f2-fa80-4106-b050-1b70f1e34cf8
#
#         corpus_repository
# 1486         ArrayExpress
# 1492         ArrayExpress
# 1494         ArrayExpress
# 1495         ArrayExpress
# 1498         ArrayExpress
# ...                   ...
# 7929780           UniProt
# 7929804           UniProt
# 7929825           UniProt
# 7929828           UniProt
# 7929829           UniProt
#
# [1341556 rows x 10 columns]

# %%
df_acc_match1['corpus_repository'].drop_duplicates().tolist()
# Out:
# ['ArrayExpress',
#  'BioStudies',
#  'BioProject',
#  'European Nucleotide Archive',
#  nan,
#  'CATH',
#  'ChEMBL',
#  'Complex Portal (CP)',
#  'NCBI dbGaP (DataBase of Genotypes And Phenotypesgenotypes and phenotypes)',
#  'Harvard Dataverse',
#  'GigaScience Database',
#  'Dryad',
#  'Zenodo',
#  'The Global Biodiversity Information Facility',
#  'PANGAEA',
#  'NASA Ocean Biology Distributed Active Archive Center',
#  'Mercator Ocean International',
#  'NOAA National Centers for Environmental Information',
#  'figshare',
#  'Mendeley',
#  'EBRAINS',
#  'Human Brain Project Neuroinformatics Platform',
#  'Portail Data INRAE',
#  'F1000Research',
#  'MX-RDR',
#  'ECMWF',
#  'CaltechDATA',
#  'Ocean Biogeographic Information System',
#  'Environmental Data Initiative',
#  'VLIZ',
#  'The Network Data Exchange - NDEx',
#  'GBIF Secretariat',
#  'MorphoBank',
#  'University of Bath',
#  'Earth System Grid Federation',
#  'The Cancer Imaging Archive',
#  'F1000 Research Limited',
#  'FaceBase (www.facebase.org)',
#  'Open Context',
#  'CORA.Repositori de Dades de Recerca',
#  'USC ISI Synapse Repository',
#  'SBGrid Data Bank',
#  'Dryad Digital Repository',
#  'The National Institute of Water and Atmospheric Research (NIWA)',
#  'Norwegian Polar Institute',
#  'British Antarctic Survey',
#  'ImmPort',
#  'U.S. Geological Survey',
#  'The University of Sheffield',
#  'Microbiology Society',
#  'Mendeley Data',
#  'NASA Planetary Data System',
#  'NERC Environmental Information Data Centre',
#  'V. N. Karazin Kharkiv National University',
#  'GigaScience',
#  'NSF Arctic Data Center',
#  'Atmospheric Radiation Measurement (ARM) Archive, Oak Ridge National Laboratory (ORNL), Oak Ridge, TN (US);',
#  'Atmospheric Radiation Measurement (ARM) Archive, Oak Ridge National Laboratory (ORNL), Oak Ridge, TN (US); ARM Data Center, Oak Ridge National Laboratory (ORNL), Oak Ridge, TN (United States)',
#  'University of Iowa',
#  'Biodiversidata',
#  'Wellcome Open Research',
#  'NASA EOSDIS Land Processes Distributed Active Archive Center',
#  'Ukrainian Nature Conservation Group (NGO)',
#  'I. I. Schmalhausen Institute of Zoology',
#  'IEEE DataPort',
#  'PhysioNet',
#  'Apollo - University of Cambridge Repository',
#  'AmeriFlux; University of California, Berkeley',
#  'AmeriFlux; University of Wisconsin',
#  'AmeriFlux; Indiana University',
#  'AmeriFlux; United States Department of Agriculture',
#  'Openneuro',
#  'CIRAD Dataverse',
#  'UCAR/NCAR - Research Data Archive',
#  'Bielefeld University',
#  'GSA Journals',
#  'Movebank Data Repository',
#  'Harte Research Institute',
#  'Wellcome Trust',
#  'Royal Belgian Institute of Natural Sciences',
#  'Belgian Biodiversity Platform',
#  'University of Liverpool',
#  'BonaRes Data Centre (Leibniz Centre for Agricultural Landscape Research (ZALF))',
#  'Baobab',
#  'SEDOO OMP',
#  'KNB Data Repository',
#  'NASA Goddard Earth Sciences Data and Information Services Center',
#  '4TU.ResearchData',
#  'Institute of Biology of Komi Scientific Centre of the Ural Branch of the Russian Academy of Sciences',
#  'Cornell Institute for Social and Economic Research',
#  'Palisades, NY: NASA Socioeconomic Data and Applications Center (SEDAC)',
#  'Groningen Growth and Development Centre',
#  'Optica Publishing Group',
#  'Broad Institute of MIT and Harvard',
#  'NERC EDS Environmental Information Data Centre',
#  'University of Michigan',
#  'Integrated Resource for Reproducibility in Macromolecular Crystallography',
#  'Lancaster University',
#  'SHARE–ERIC',
#  'University of Leeds',
#  'Bolin Centre Database',
#  'University of Edinburgh. IGMM. MRC Human Genetics Unit',
#  'University of Edinburgh. IGMM. MRC Human Genetics Unit.',
#  'CRCNS.org',
#  'G-Node',
#  'University of Edinburgh (UK) and Washington University (St Louis, Missouri)',
#  'The Smithsonian Institution',
#  'University of Illinois at Urbana-Champaign',
#  'GBIF Benin',
#  'iNaturalist.org',
#  'Southwestern Pacific Ocean Biogeographic Information System (OBIS) Node',
#  'Staatliches Museum für Naturkunde Stuttgart',
#  'Plazi.org taxonomic treatments database',
#  'U.S. EPA Office of Research and Development (ORD)',
#  'Oak Ridge National Laboratory (ORNL), Oak Ridge, TN (United States). Oak Ridge Leadership Computing Facility (OLCF); Oak Ridge National Laboratory (ORNL), Oak Ridge, TN (United States)',
#  'UK Data Service',
#  'University of St Andrews',
#  'Institute of Tropical Medicine Antwerp',
#  'SEANOE',
#  'CBGP (UMR INRA, Cirad, IRD, Montpellier SupAgro)',
#  'NSIDC',
#  'SCAR - Microbial Antarctic Resource System',
#  'University of Glasgow',
#  'DataverseNL',
#  'United Nations Environment Programme World Conservation Monitoring Centre (UNEP-WCMC)',
#  'UN Environment Programme World Conservation Monitoring Centre (UNEP-WCMC)',
#  'Biodiversity Data Journal',
#  'Göttingen Research Online / Data',
#  'Carbon Dioxide Information Analysis Center (CDIAC)',
#  'Neotoma Paleoecological Database',
#  'UCAR/NCAR - Earth Observing Laboratory',
#  'NASA National Snow and Ice Data Center Distributed Active Archive Center',
#  'NASA Physical Oceanography Distributed Active Archive Center',
#  'Arctic Data Center',
#  'University of Edinburgh. College of Medicine & Veterinary Medicine',
#  'CSIRO',
#  'DANS Data Station Physical and Technical Sciences',
#  'DANS Data Station Social Sciences and Humanities',
#  'Karolinska Institutet',
#  'DataverseNO',
#  'SHARE-ERIC',
#  'Texas Data Repository',
#  'Cape Peninsula University of Technology',
#  'Invasive Species Specialist Group ISSG',
#  'MultiSector Dynamics - Living, Intuitive, Value-adding, Environment',
#  'UNAVCO, Inc.',
#  'University of Southampton',
#  'EMODnet Bathymetry Consortium',
#  'Istituto Nazionale di Geofisica e Vulcanologia (INGV)',
#  'NERC EDS British Oceanographic Data Centre NOC',
#  'University of Reading',
#  'UNC Dataverse',
#  'Australian Antarctic Data Centre',
#  'physionet.org',
#  'NITRC',
#  'NIMH Data Repositories',
#  'INTERVALS',
#  'ISEC PRESS',
#  'Marine Data Archive',
#  'CIBIO (Research Center in Biodiversity and Genetic Resources) Portugal',
#  'Environmental System Science Data Infrastructure for a Virtual Ecosystem; CDIAC-FF, Research Institute for Environment, Energy, and Economics, Appalachian State University',
#  'National Institute for Environmental Studies',
#  'LIfBi Leibniz Institute for Educational Trajectories',
#  'Satellite Application Facility on Climate Monitoring (CM SAF)',
#  'MassIVE',
#  'UNITE Community',
#  'University of Melbourne',
#  'AmeriFlux; USDA Forest Service',
#  'Global Carbon Project',
#  'GESIS Data Archive',
#  'Figshare',
#  'University of Oxford',
#  'Coherent X-ray Imaging Data Bank (Lawrence Berkeley National Laboratory); The Scripps Research Institute, DESY, \nArizona State University, Trinity College, SLAC, Uppsala University, University of Hamburg',
#  'Coherent X-ray Imaging Data Bank (Lawrence Berkeley National Laboratory); Arizona State University, The Scripps \nResearch Institute, CFEL, SLAC, Uppsala University, Universidad Autónoma de Madrid, Max-Planck-Institut für \nmedizinische Forschung, University of Hamburg, Trinity College Dublin',
#  'Coherent X-ray Imaging Data Bank (Lawrence Berkeley National Laboratory); The Scripps Research Institute, Vrije \nUniversiteit Brussel, University of North Carolina Chapel Hill Medical School, University of Hamburg, CFEL, Arizona State \nUniversity, Clinical Research Institute of Montreal, SLAC',
#  'Coherent X-ray Imaging Data Bank (Lawrence Berkeley National Laboratory); University of Southern California, \nCleveland \nClinic, Center for Free Electron Laser Science, Arizona State Universiy, University of California Los Angeles, SLAC \nNational \nAccelerator Laboratory, Harvard University, ShanghaiTech University',
#  'Recherche Data Gouv',
#  'NASA Level 1 and Atmosphere Archive and Distribution System Distributed Active Archive Center',
#  'UC San Diego Library Digital Collections',
#  'University College London',
#  'University of Edinburgh. Centre for Clinical Brain Sciences.',
#  'Open Power System Data',
#  'KU Leuven RDR',
#  'National Institute of Standards and Technology',
#  'Iowa State University',
#  'Natural History Museum',
#  'Biological and Chemical Oceanography Data Management Office (BCO-DMO)',
#  'National Institutes of Health (NIH)',
#  'The NIH Figshare Archive',
#  'Government of Canada',
#  'U.S. Department of Energy Systems Biology Knowledgebase',
#  'NERC EDS Centre for Environmental Data Analysis',
#  'PADC',
#  'Interdisciplinary Earth Data Alliance (IEDA)',
#  'Minneapolis, MN: IPUMS',
#  'Climate Hazards Center',
#  'NERC EDS UK Polar Data Centre',
#  'SRDA - Survey Research Data Archive Taiwan',
#  'GFZ Data Services',
#  'Figshare+',
#  'INDIGEO',
#  'Ifremer - Laboratoire Comportement des Structures en Mer',
#  'Shom',
#  'Digital Rocks Portal',
#  'EnviDat',
#  'University of Veterinary Medicine Vienna',
#  'Government of Canada ',
#  'NASA Langley Atmospheric Science Data Center Distributed Active Archive Center',
#  'University of Edinburgh. School of Informatics',
#  'Data Repository for the University of Minnesota (DRUM)',
#  'SciLifeLab',
#  'Cornell Lab of Ornithology',
#  'Observation.org',
#  'The Open University',
#  'University of Edinburgh on behalf of Software Sustainability Institute',
#  'SOEP Socio-Economic Panel Study',
#  'Leibniz Centre for Agricultural Landscape Research (ZALF), Muencheberg (Germany)',
#  'Institut Laue-Langevin (ILL)',
#  'The Data Repository for the University of Minnesota',
#  'AmeriFlux; University of Colorado',
#  'GUDMAP (www.gudmap.org)',
#  'CyVerse Data Commons',
#  'Botanic Garden Meise',
#  'Coherent X-ray Imaging Data Bank (Lawrence Berkeley National Laboratory); KEK High Energy Accelerator Research Organization, Japan Synchrotron Radiation Research Institute, Japan Science and Technology Agency, RIKEN SPring-8 Center, Kyoto University',
#  'ForestPlots.net',
#  'Environmental System Science Data Infrastructure for a Virtual Ecosystem; Advanced Global Atmospheric Gases Experiment (AGAGE)',
#  'LUIS',
#  'Janelia Research Campus',
#  'European Synchrotron Radiation Facility',
#  'ASEP repository',
#  'Science Data Bank',
#  'The Hive: University of Utah Research Data Repository',
#  'Minneapolis, MN: IPUMS and ICF',
#  'Cambridge Crystallographic Data Centre',
#  'Oak Ridge National Laboratory (ORNL), Oak Ridge, TN (United States)',
#  'London School of Hygiene & Tropical Medicine',
#  'ZfKD – German Center for Cancer Registry Data at the RKI',
#  'Mahboob Elahi',
#  'Varieties of Democracy (V-Dem) Project',
#  'Borealis',
#  'Ag Data Commons',
#  'Newcastle University',
#  'RMIT University',
#  'CREAF - Centre de Recerca Ecol?gica i Aplicacions Forestals',
#  'University of Dundee',
#  'Universidade dos Açores',
#  'University of Birmingham',
#  'NIMH Data Archive',
#  'OpenProceedings.org',
#  'NERC EDS National Geoscience Data Centre',
#  'DANDI Archive',
#  'University of South-Eastern Norway',
#  'The University of North Carolina at Chapel Hill University Libraries',
#  'National Air and Space Museum',
#  'Uppsala University',
#  'Eawag: Swiss Federal Institute of Aquatic Science and Technology',
#  'Radboud University',
#  'Archive2014',
#  'The United States Environmental Protection Agency’s Center for Computational Toxicology and Exposure',
#  'SysTax',
#  'Institute of Biodiversity, Animal Health and Comparative Medicine, College of Medical, Veterinary and Life Sciences, University of Glasgow',
#  'BORDaR: Bournemouth Online Research Data Repository',
#  'University of Amsterdam / Amsterdam University of Applied Sciences',
#  'NSD - Norsk senter for forskningsdata AS',
#  'ISIS Facility',
#  'Institute for Marine and Antarctic Studies (IMAS), University of Tasmania (UTAS)',
#  'The University of Queensland',
#  'World Data Center for Climate (WDCC) at DKRZ',
#  'Tyumen State University',
#  'Peking University Open Research Data Platform',
#  'Copernicus Monitoring Environment Marine Service (CMEMS)',
#  'University Libraries, Virginia Tech',
#  'Edmond',
#  'UMS PatriNat (AFB-CNRS-MNHN), Paris',
#  'Staten Island Museum',
#  'Apeiron',
#  'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#  'Natural History Museum Rotterdam',
#  'International Union for Conservation of Nature',
#  'Instituto de Ecología y Biodiversidad',
#  'Panorama Public',
#  'LBNL Materials Project; Lawrence Berkeley National Laboratory (LBNL), Berkeley, CA (United States)',
#  'e-cienciaDatos',
#  'CERN Open Data Portal',
#  'NCBI/GenBank',
#  'NOAA ESRL GML CCGG Group',
#  'Altai State University',
#  'Auburn University',
#  'TalkBank',
#  'Unpublished',
#  'University of Edinburgh. School of Informatics. Systems Neuroscience group',
#  'University of Edinburgh. School of Physics and Astronomy. Institute for Condensed Matter and Complex Systems',
#  'University of Gothenburg',
#  'The University of Edinburgh. School of Geosciences. Institute of Geography',
#  'University of Edinburgh. Centre for Clinical Brain Sciences',
#  'British Oceanographic Data Centre, National Oceanography Centre, NERC, UK',
#  'Umeå University',
#  'EPrints Repo',
#  'UCAR/NCAR Earth System Grid',
#  'DataFirst',
#  'Colchester, Essex: UK Data Archive',
#  'Nordicana D',
#  'Faculty of engineering, Lund University',
#  '4TU.Centre for Research Data',
#  'British Oceanographic Data Centre, Natural Environment Research Council',
#  'Data Repository for the University of Minnesota',
#  'DR-NTU (Data)',
#  'Global Precipitation Climatology Centre (GPCC) at Deutscher Wetterdienst',
#  'Digital.CSIC',
#  'AIDA',
#  'University of Edinburgh. Edinburgh Medical School',
#  'Adis Journals',
#  'Utah State University',
#  'Bond University',
#  'University of Edinburgh',
#  'WSL Institute for Snow and Avalanche Research SLF',
#  'Senckenberg',
#  'Purdue University Research Repository',
#  'TU Delft',
#  'Eindhoven University of Technology',
#  'Columbia University',
#  'QDR Main Collection',
#  'Barcode of Life Data Systems',
#  'QuTech',
#  'The University of Sydney',
#  'Coherent X-ray Imaging Data Bank (Lawrence Berkeley National Laboratory); Uppsala University, CFEL, Arizona State University, La Trobe University, University of Wisconsin, SLAC National Accelerator Laboratory',
#  "ORNLTESSFA (Oak Ridge National Lab's Terrestrial Ecosystem Science Scientific Focus Area (ORNL TES SFA))",
#  'Compiled by NOAA Global Monitoring Division: Boulder, Colorado, U.S.A.',
#  'Landcare Research NZ Ltd',
#  'Wageningen University',
#  'Catalogue of Life',
#  'University of Cape Town',
#  'RepOD',
#  'Chrysomelidae Recording Scheme',
#  'World Values Survey Association',
#  'Copernicus Climate Change Service (C3S) Climate Data Store (CDS)',
#  'MDA',
#  'Minneapolis, MN: University of Minnesota',
#  'Materials Cloud',
#  'Technical University of Denmark',
#  'Unisanté, University Center for Primary Care and Public Health',
#  'SupraBank',
#  'Ifremer',
#  'Observatoire global du Saint-Laurent',
#  "King's College London",
#  'MyGeoHUB',
#  'Middlebury',
#  'University of Arizona Research Data Repository',
#  'Museum für Naturkunde Berlin (MfN) - Leibniz Institute for Evolution and Biodiversity Science',
#  'Sikt - Norwegian Agency for Shared Services in Education and Research',
#  'National Heart, Lung, and Blood Institute',
#  'SciELO journals',
#  'Monash University',
#  'Science and Technology Facilities Council',
#  'Institute for Health Metrics and Evaluation (IHME)',
#  'MGnify',
#  'University of Bristol',
#  'HZB Data Service',
#  'University of Edinburgh. Edinburgh Medical School. Usher Institute',
#  'The Francis Crick Institute',
#  'Swedish University of Agricultural Sciences',
#  'Data Archiving and Networked Services (DANS)',
#  'Rodare',
#  'University of Manchester',
#  'The University of Adelaide',
#  'Utrecht University',
#  'Universitat de les Illes Balears',
#  'Databrary',
#  'ChecklistBank',
#  'Moscow Pedagogical State University (MPSU).',
#  'University of Debrecen',
#  'BioRxiv',
#  'The University of Western Australia',
#  'University of Exeter',
#  'ADA Dataverse',
#  'National Cancer Institute',
#  'Royal Belgian Institute for Space Aeronomy',
#  'Erasmus University Rotterdam (EUR)',
#  'SUNScholarData',
#  'University of Edinburgh. School of Physics and Astronomy',
#  'DOE Joint Genome Institute',
#  'Department of Psychology',
#  'Centre for Environmental Data Analysis (CEDA)',
#  'Cardiff University',
#  'Institute of Marine Research',
#  'German Centre for Integrative Biodiversity Research (iDiv) Halle-Jena-Leipzig',
#  'Eemeli Holopainen',
#  'UCAR/NCAR',
#  'Vivli',
#  'University of Technology Sydney',
#  'National Energy Technology Laboratory - Energy Data eXchange; NETL',
#  'Biological Magnetic Resonance Bank',
#  'Curtin University',
#  'University of Copenhagen',
#  'Institute of Space and Astronautical Science, Japan Aerospace Exploration Agency',
#  'EARSeL eProceedings',
#  'RWTH Aachen University',
#  'the Infectious Diseases Data Observatory',
#  'NASA LANCE MODIS at the MODAPS',
#  'QsarDB repository (https://qsardb.org/)',
#  'dataUBFC - Atelier de la donnée de Bourgogne-Franche-Comté',
#  'Queensland University of Technology (QUT), Australia',
#  'Jülich DATA',
#  'University of Colorado Boulder',
#  'NOAA Global Monitoring Laboratory',
#  'University of Newcastle',
#  'University of Sussex',
#  'Johns Hopkins Research Data Repository',
#  'Cornell University Library',
#  'Universidad del Rosario',
#  'Pandora',
#  'Environmental System Science Data Infrastructure for a Virtual Ecosystem; Carbon Dioxide Information Analysis Center (CDIAC), Oak Ridge National Laboratory (ORNL), Oak Ridge, TN (United States)',
#  'Cefas',
#  'CNGB',
#  'University of Salento',
#  'Stockholm University',
#  'Materials Data Facility',
#  'Polar Data Centre; British Antarctic Survey, Natural Environment Research Council; Cambridge, CB3 0ET, UK.',
#  'Westerdijk Fungal Biodiversity Institute',
#  'Humboldt-Universität zu Berlin',
#  'UK Energy Research Centre',
#  'Instituto de Ciencias del Mar (CSIC)',
#  'data.sciencespo',
#  'OGS - Istituto Nazionale di Oceanografia e Geofisica Sperimentale',
#  'Dublin Institute of Technology',
#  'National Agricultural Library - ARS - USDA',
#  'Open Data Commons for Traumatic Brain Injury (ODC-TBI)',
#  'Clinical Practice Research Datalink',
#  'ADLRO',
#  'Cardiff Univeristy',
#  'DANS Data Station Archaeology',
#  "IT'IS Foundation",
#  'University of Southern California Digital Library (USC.DL)',
#  'The International Plant Names Index Collaborators',
#  'RANGSIT UNIVERSITY',
#  'ORCID',
#  'Elsevier BV',
#  'Stanford Digital Repository',
#  'Research Institute for Nature and Forest (INBO)',
#  'Technical University of Darmstadt',
#  'Axiom Data Science',
#  'GMBA-EarthEnv',
#  'International Institute for Applied Systems Analysis (IIASA)',
#  'Global Precipitation Climatology Centre (GPCC)',
#  'Nutrient Data Laboratory, Beltsville Human Nutrition Research Center, ARS, USDA',
#  'Mannheim University Library',
#  'INDEPTH Network',
#  'University of Edinburgh. Institute of Genetics and Cancer. MRC Human Genetics Unit',
#  'Université de Genève, Yareta',
#  'University of Edinburgh. School of Physics & Astronomy. Institute of Condensed Matter and Complex Systems',
#  'University Of Leeds',
#  'University of Edinburgh. College of Medicine & Veterinary Medicine. Royal (Dick) School of Veterinary Studies. The Roslin Institute',
#  'University of Leicester',
#  'University of Edinburgh. School of Physics and Astronomy. Institute of Condensed Matter and Complex Systems',
#  'Imperial College London',
#  'Gouvernement du Canada',
#  'University of Ljubljana, Faculty of Social Sciences, Slovenian Social Science Data Archives (ADP)',
#  'Palisades, NY:  Socioeconomic Data and Applications Center (SEDAC)',
#  'Loughborough University',
#  'Next Generation Ecosystems Experiment - Arctic, Oak Ridge National Laboratory (ORNL), Oak Ridge, TN (US); NGEE Arctic, Oak Ridge National Laboratory (ORNL), Oak Ridge, TN (United States)',
#  'Cranfield Online Research Data (CORD)',
#  'University of Edinburgh. College of Medicine and Veterinary Medicine. School of Clinical Sciences. Centre for Clinical Brain Sciences',
#  'European X-Ray Free-Electron Laser Facility GmbH',
#  'The University of Auckland',
#  'Eurostat',
#  'Atlas of Living Australia',
#  'University of Edinburgh. Usher Institute',
#  'Johns Hopkins Turbulence Databases',
#  'Open Data Commons for Spinal Cord Injury (ODC-SCI)',
#  'Leibniz-Institut für Pflanzenbiochemie',
#  'Royal Holloway, University of London',
#  'NSD – Norwegian Centre for Research Data',
#  'Carnegie Mellon University',
#  'Southern Cross University',
#  'University of York',
#  'University of Edinburgh. Centre for Cognitive Ageing and Cognitive Epidemiology',
#  'National Renewable Energy Laboratory - Data (NREL-DATA), Golden, CO (United States); National Renewable Energy Laboratory',
#  'IRI Data Library',
#  'Portail Data Inra Dataverse',
#  'NERC British Atmospheric Data Centre',
#  'International VLBI Service for Geodesy and Astrometry, GFZ Data Services',
#  'TUHH Universitätsbibliothek',
#  'ASHA journals',
#  'Wageningen University & Research',
#  'Laboratoire Chrono-environnement (UMR 6249)',
#  'National Research Council of Canada',
#  'University of Edinburgh. College of Medicine and Veterinary Medicine, Centre for Clinical Brain Sciences & Edinburgh Imaging',
#  'University of Edinburgh. College of Medicine and Veterinary Medicine. Centre for Clinical Brain Sciences',
#  'Edinburgh Medical School. Biomedical Sciences. University of Edinburgh',
#  'University of Edinburgh. School of Chemistry',
#  'University of Edinburgh. Edinburgh Medical School. Biomedical Sciences',
#  'Paleobiology Database',
#  'International Soil Carbon Network (ISCN);',
#  'CSIC-UIB - Instituto de Física Interdisciplinar y Sistemas Complejos (IFISC)',
#  'Australian Ocean Data Network',
#  'NIMH Data Archives',
#  'ihi - Ifakara Health Institute',
#  'University of Edinburgh, School of Biological Sciences',
#  'TERN',
#  'Coherent X-ray Imaging Data Bank (Lawrence Berkeley National Laboratory); Indiana University Bloomington',
#  'Leiden University',
#  'University of Edinburgh. Institute of Genetics & Molecular Medicine (IGMM)',
#  'BIBB - Federal Institute for Vocational Education and Training',
#  'University of South Australia',
#  'Coherent X-ray Imaging Data Bank (Lawrence Berkeley National Laboratory); Uppsala University, SLAC National \nAccelerator Laboratory, CFEL, University of Hamburg, Arizona State University, University of Wisconsin, La Trobe \nUniversity',
#  'University of Edinburgh, School of Chemistry',
#  'Coherent X-ray Imaging Data Bank (Lawrence Berkeley National Laboratory); Beijing Computational Science Research Center, Max-Planck-Institut für medizinische Forschung, The European XFEL, Arizona State University, SLAC, Paul Scherrer Institute',
#  'Illinois State Water Survey, Prairie Research Institute, University of Illinois at Urbana-Champaign',
#  'World Glacier Monitoring Service (WGMS)',
#  'Lawrence Berkeley National Laboratory (LBNL), Berkeley, CA (United States)',
#  'Wiley',
#  'AmeriFlux; Lawrence Livermore National Laboratory',
#  'Environmental System Science Data Infrastructure for a Virtual Ecosystem; Carbon Dioxide Information Analysis Center (CDIAC); Oak Ridge National Laboratory (ORNL), Oak Ridge, TN (United States)',
#  'University of Edinburgh. School of Biological Sciences',
#  'Deutsches GeoForschungsZentrum GFZ',
#  'Brill Online',
#  'ORNL Distributed Active Archive Center',
#  'Coherent X-ray Imaging Data Bank (Lawrence Berkeley National Laboratory); Uppsala University, SLAC National \nAccelerator Laboratory, Yale University, Diamond Light Source, Lawrence Berkeley National Laboratory',
#  'Coherent X-ray Imaging Data Bank (Lawrence Berkeley National Laboratory); Uppsala University, SLAC National \nAccelerator Laboratory, ...',
#  'Deutsches Zentrum für Altersfragen',
#  'Geoscience Australia',
#  'University of Edinburgh, School of Chemisty',
#  'f1000research.com',
#  'U.S. Antarctic Program Data Center (USAP-DC), via National Snow and Ice Data Center (NSIDC)',
#  'The Joint Institute for the Study of the Atmosphere and Ocean (JISAO)',
#  'Durham University',
#  'Edinburgh Imaging, University of Edinburgh',
#  'Synapse',
#  'Not Available',
#  'BGI Shenzhen',
#  'The European Genome-phenome Archive(EGA)',
#  'The Electron Microscopy Data Bank (EMDB)',
#  'Electron Microscopy Public Image Archive (EMPIAR)',
#  'Ensembl',
#  'Genome assembly database',
#  'The International Genome Sample Resource',
#  'Gene Expression Omnibus (GEO)',
#  'HUGO Gene Nomenclature Committee',
#  'Human induced pluripotent stem cell initiative',
#  'IntAct',
#  'InterPro',
#  'MetaboLights',
#  'The Protein Data Bank',
#  'Pfam Protein Families',
#  'PRIDE Proteomics Identification Database',
#  'Reactome',
#  'NCBI Reference Sequence Database',
#  'dbSNP Reference SNP',
#  'RNAcentral',
#  'TreeFam',
#  'UniParc',
#  'UniProt']

# %%
pivot = df_acc_match1.pivot_table(
    values=["corpus_id", "corpus_repository"],
    index="repository_europepmc",
    aggfunc={
        "corpus_id": len,
        "corpus_repository": lambda x: x.drop_duplicates().tolist(),
    },
    observed=True,
).reset_index().rename(columns={'corpus_id': 'count_matched_in_corpus'})

# %%
# create descriptive stats table
df_repository_stats = df_repository.merge(pivot, how='left', on='repository_europepmc')
df_repository_stats['count_matched_in_corpus'] = df_repository_stats['count_matched_in_corpus'].fillna(value=0).astype(int)
df_repository_stats['corpus_repository'] = df_repository_stats['corpus_repository'].fillna(value="")
df_repository_stats['pct_matched_in_corpus'] = df_repository_stats['count_matched_in_corpus'] / df_repository_stats['row_count_europepmc']
df_repository_stats = df_repository_stats.rename(columns={'corpus_repository': 'names_in_corpus'})
df_repository_stats = df_repository_stats.set_index('repository_europepmc', verify_integrity=True).sort_index()
# rearrange columns
column_order = ['row_count_europepmc', 'count_matched_in_corpus', 'pct_matched_in_corpus', 'names_in_corpus']
df_repository_stats = df_repository_stats[column_order]

# %%
df_repository_stats
# Out:
#                       row_count_europepmc  count_matched_in_corpus  \
# repository_europepmc
# alphafold                            1316                        0
# arrayexpress                        14594                     7493
# bia                                    91                       19
# biomodels                             839                        0
# bioproject                          92712                    46059
# biosample                           18365                     5128
# biostudies                            268                      106
# brenda                               7347                        0
# cath                                 1745                      456
# cellosaurus                         28849                        0
# chebi                                   5                        0
# chembl                               3973                      897
# complexportal                         159                       48
# dbgap                                7906                      613
# doi                                 99812                    17207
# ebisc                                1313                        0
# efo                                   575                        0
# ega                                  4987                      704
# emdb                                 7256                     1660
# empiar                                812                      270
# ensembl                            104723                    15151
# eudract                             14652                        0
# gca                                 39237                    10234
# gen                               2627276                   467598
# geo                                270564                   116299
# gisaid                              24934                        0
# go                                 371962                        0
# hgnc                                 6295                      457
# hipsci                                  8                        3
# hpa                                 18101                        0
# igsr                                19432                     7293
# intact                                 50                        2
# interpro                            17922                     5666
# metabolights                          747                      397
# metagenomics                           33                       13
# mint                                   47                        0
# nct                                911196                        0
# omim                               241864                        0
# orphadata                             890                        0
# pdb                                786794                   221048
# pfam                                49126                    17865
# pxd                                 17209                     8559
# reactome                             7464                     1485
# refseq                             519339                   107801
# refsnp                             955107                   187653
# rfam                                 3796                        0
# rhea                                   89                        0
# rnacentral                            740                       56
# rrid                                13244                        0
# treefam                               236                       85
# uniparc                               532                       75
# uniprot                            608441                    93156
#
#                       pct_matched_in_corpus  \
# repository_europepmc
# alphafold                          0.000000
# arrayexpress                       0.513430
# bia                                0.208791
# biomodels                          0.000000
# bioproject                         0.496797
# biosample                          0.279227
# biostudies                         0.395522
# brenda                             0.000000
# cath                               0.261318
# cellosaurus                        0.000000
# chebi                              0.000000
# chembl                             0.225774
# complexportal                      0.301887
# dbgap                              0.077536
# doi                                0.172394
# ebisc                              0.000000
# efo                                0.000000
# ega                                0.141167
# emdb                               0.228776
# empiar                             0.332512
# ensembl                            0.144677
# eudract                            0.000000
# gca                                0.260825
# gen                                0.177978
# geo                                0.429839
# gisaid                             0.000000
# go                                 0.000000
# hgnc                               0.072597
# hipsci                             0.375000
# hpa                                0.000000
# igsr                               0.375309
# intact                             0.040000
# interpro                           0.316148
# metabolights                       0.531459
# metagenomics                       0.393939
# mint                               0.000000
# nct                                0.000000
# omim                               0.000000
# orphadata                          0.000000
# pdb                                0.280948
# pfam                               0.363657
# pxd                                0.497356
# reactome                           0.198955
# refseq                             0.207573
# refsnp                             0.196473
# rfam                               0.000000
# rhea                               0.000000
# rnacentral                         0.075676
# rrid                               0.000000
# treefam                            0.360169
# uniparc                            0.140977
# uniprot                            0.153106
#
#                                                         names_in_corpus
# repository_europepmc
# alphafold
# arrayexpress                                             [ArrayExpress]
# bia                                                        [BioStudies]
# biomodels
# bioproject                    [BioProject, European Nucleotide Archive]
# biosample                            [nan, European Nucleotide Archive]
# biostudies                                                 [BioStudies]
# brenda
# cath                                                             [CATH]
# cellosaurus
# chebi
# chembl                                                         [ChEMBL]
# complexportal                                     [Complex Portal (CP)]
# dbgap                 [NCBI dbGaP (DataBase of Genotypes And Phenoty...
# doi                   [Harvard Dataverse, GigaScience Database, Drya...
# ebisc
# efo
# ega                          [The European Genome-phenome Archive(EGA)]
# emdb                         [The Electron Microscopy Data Bank (EMDB)]
# empiar                [Electron Microscopy Public Image Archive (EMP...
# ensembl                                                       [Ensembl]
# eudract
# gca                                          [Genome assembly database]
# gen                   [European Nucleotide Archive, The Internationa...
# geo                   [Gene Expression Omnibus (GEO), European Nucle...
# gisaid
# go
# hgnc                                 [HUGO Gene Nomenclature Committee]
# hipsci                 [Human induced pluripotent stem cell initiative]
# hpa
# igsr                         [The International Genome Sample Resource]
# intact                                                         [IntAct]
# interpro                                                     [InterPro]
# metabolights                                             [MetaboLights]
# metagenomics                                                   [MGnify]
# mint
# nct
# omim
# orphadata
# pdb                                             [The Protein Data Bank]
# pfam                                            [Pfam Protein Families]
# pxd                          [PRIDE Proteomics Identification Database]
# reactome                                                     [Reactome]
# refseq                               [NCBI Reference Sequence Database]
# refsnp                                            [dbSNP Reference SNP]
# rfam
# rhea
# rnacentral                                                 [RNAcentral]
# rrid
# treefam                                                       [TreeFam]
# uniparc                                                       [UniParc]
# uniprot                          [UniProt, European Nucleotide Archive]

# %%
df_repository_stats.to_clipboard()

# %%
df_uniprot = df_acc_corpus_merge[df_acc_corpus_merge["repository_europepmc"]=="uniprot"]
df_uniprot.shape
# Out:
# (608571, 10)

# %%
df_uniprot_corpusmatch = df_uniprot[df_uniprot["corpus_id"].notna()]
df_uniprot_corpusmatch.shape
# Out:
# (93156, 10)

# %%
# sample by doi
random_seed = 113
_unique_dois = df_uniprot_corpusmatch["DOI"].drop_duplicates()
_sample_dois = _unique_dois.sample(n=50, random_state=random_seed)
df_uniprot_corpusmatch_sample = df_uniprot[df_uniprot["DOI"].isin(_sample_dois)].sort_values("DOI")
df_uniprot_corpusmatch_sample["found_in_corpus"] = df_uniprot_corpusmatch_sample["corpus_id"].notna()
df_uniprot_corpusmatch_sample["doi_index"] = df_uniprot_corpusmatch_sample.groupby("DOI").ngroup()

# %%
df_uniprot_corpusmatch_sample.to_clipboard(index=False)

# %%
df_uniprot_pubnotincorpus = df_uniprot[~(df_uniprot["DOI"].isin(corpus_dois))]
df_uniprot_pubnotincorpus.shape
# Out:
# (280817, 10)

# %%
df_uniprot_pubnotincorpus["DOI"].nunique()
# Out:
# 33162

# %%
_unique_dois = df_uniprot_pubnotincorpus["DOI"].drop_duplicates()
_sample_dois = _unique_dois.sample(n=50, random_state=random_seed)
df_uniprot_pubnotincorpus_sample = df_uniprot[df_uniprot["DOI"].isin(_sample_dois)].sort_values("DOI")
df_uniprot_pubnotincorpus_sample["found_in_corpus"] = df_uniprot_pubnotincorpus_sample["corpus_id"].notna()
df_uniprot_pubnotincorpus_sample["doi_index"] = df_uniprot_pubnotincorpus_sample.groupby("DOI").ngroup()

# %%
column_order = """doi_index	DOI	accession_number	found_in_corpus	PMCID	EXTID	SOURCE	repository_europepmc	PMID	accession_number_upper	corpus_id	corpus_repository""".split()
df_uniprot_pubnotincorpus_sample[column_order].to_clipboard(index=False)

# %%
matched_corpus_ids = df_acc_corpus_merge["corpus_id"].dropna().unique()
df_corpus_unmatched = df_corpus[~(df_corpus.index.isin(matched_corpus_ids))]

# %%
df_corpus_unmatched_uniprot = df_corpus_unmatched[df_corpus_unmatched["repository"].str.lower()=="uniprot"]
df_corpus_unmatched_uniprot.shape
# Out:
# (66169, 9)

# %%
_unique_dois = df_corpus_unmatched_uniprot["publication"].drop_duplicates()
_sample_dois = _unique_dois.sample(n=50, random_state=random_seed)
df_corpus_unmatched_uniprot_sample = df_corpus_unmatched_uniprot[df_corpus_unmatched_uniprot["publication"].isin(_sample_dois)].sort_values("publication")
df_corpus_unmatched_uniprot_sample["found_in_corpus"] = df_corpus_unmatched_uniprot_sample.index.isin(df_acc_corpus_merge["corpus_id"].dropna().unique())
df_corpus_unmatched_uniprot_sample["doi_index"] = df_corpus_unmatched_uniprot_sample.groupby("publication").ngroup()

# %%
df_corpus_unmatched_uniprot_sample.to_clipboard()

# %% [markdown]
# ### Protein Data Bank

# %%
df_pdb = df_acc_corpus_merge[df_acc_corpus_merge["repository_europepmc"]=="pdb"]
df_pdb.shape
# Out:
# (788008, 10)

# %%
df_pdb_corpusmatch = df_pdb[df_pdb["corpus_id"].notna()]
df_pdb_corpusmatch.shape
# Out:
# (221048, 10)

# %%
# sample by doi
random_seed = 113
_unique_dois = df_pdb_corpusmatch["DOI"].drop_duplicates()
_sample_dois = _unique_dois.sample(n=50, random_state=random_seed)
df_pdb_corpusmatch_sample = df_pdb[df_pdb["DOI"].isin(_sample_dois)].sort_values("DOI")
df_pdb_corpusmatch_sample["found_in_corpus"] = df_pdb_corpusmatch_sample["corpus_id"].notna()
df_pdb_corpusmatch_sample["doi_index"] = df_pdb_corpusmatch_sample.groupby("DOI").ngroup()

# %%
df_pdb_corpusmatch_sample.to_clipboard(index=False)

# %%
df_pdb_pubnotincorpus = df_pdb[~(df_pdb["DOI"].isin(corpus_dois))]
df_pdb_pubnotincorpus.shape
# Out:
# (454155, 10)

# %%
df_pdb_pubnotincorpus["DOI"].nunique()
# Out:
# 122291

# %%
_unique_dois = df_pdb_pubnotincorpus["DOI"].drop_duplicates()
_sample_dois = _unique_dois.sample(n=50, random_state=random_seed)
df_pdb_pubnotincorpus_sample = df_pdb[df_pdb["DOI"].isin(_sample_dois)].sort_values("DOI")
df_pdb_pubnotincorpus_sample["found_in_corpus"] = df_pdb_pubnotincorpus_sample["corpus_id"].notna()
df_pdb_pubnotincorpus_sample["doi_index"] = df_pdb_pubnotincorpus_sample.groupby("DOI").ngroup()

# %%
column_order = """doi_index	DOI	accession_number	found_in_corpus	PMCID	EXTID	SOURCE	repository_europepmc	PMID	accession_number_upper	corpus_id	corpus_repository""".split()
df_pdb_pubnotincorpus_sample[column_order].to_clipboard(index=False)

# %%
matched_corpus_ids = df_acc_corpus_merge["corpus_id"].dropna().unique()
df_corpus_unmatched = df_corpus[~(df_corpus.index.isin(matched_corpus_ids))]

# %%
df_corpus_unmatched_pdb = df_corpus_unmatched[df_corpus_unmatched["repository"]=="The Protein Data Bank"]
df_corpus_unmatched_pdb.shape
# Out:
# (184986, 9)

# %%
_unique_dois = df_corpus_unmatched_pdb["publication"].drop_duplicates()
_sample_dois = _unique_dois.sample(n=50, random_state=random_seed)
df_corpus_unmatched_pdb_sample = df_corpus_unmatched_pdb[df_corpus_unmatched_pdb["publication"].isin(_sample_dois)].sort_values("publication")
df_corpus_unmatched_pdb_sample["found_in_corpus"] = df_corpus_unmatched_pdb_sample.index.isin(df_acc_corpus_merge["corpus_id"].dropna().unique())
df_corpus_unmatched_pdb_sample["doi_index"] = df_corpus_unmatched_pdb_sample.groupby("publication").ngroup()

# %%
df_corpus_unmatched_pdb_sample.to_clipboard()
